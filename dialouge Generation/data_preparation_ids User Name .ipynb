# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your file
file_path = './Synthetic-Persona-Chat/data/Synthetic-Persona-Chat_train.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dfframe
print(df.head())
# Out:
#                                      user 1 personas  \
# 0  I am 32.\nI do not want a job.\nI play video g...
# 1  I am 32.\nI play video games all day.\nI still...
# 2  I am 32.\nI play video games all day.\nI still...
# 3  I write.\nI work at mcdonald s.\nI watch youtu...
# 4  I am bald.\nI like to swim.\nMy favorite drink...
#
#                                      user 2 personas  \
# 0  My favorite drink is iced coffee.\nI have a bl...
# 1  I have a ford f150.\nI like ford cars.\nMy tru...
# 2  I can recite the movie young frankenstein word...
# 3  I want to move.\nI don t like feeling controll...
# 4  My favorite store is american eagle.\nI enjoy ...
#
#                          Best Generated Conversation
# 0  User 1: Hi! I'm [user 1's name].\nUser 2: Hi [...
# 1  User 1: Hey, how's it going?\nUser 2: Good, I'...
# 2  User 1: Hi, my name is John. What's your name?...
# 3  User 1: Hi!\nUser 2: Hey!\nUser 1: What's up?\...
# 4  User 1: Hello!\nUser 2: Hi!\nUser 1: What do y...

# %%
data_list = df.to_dict(orient='records')
data_list[0:5]
# Out:
# [{'user 1 personas': 'I am 32.\nI do not want a job.\nI play video games all day.\nI still live at home with my parents.',
#   'user 2 personas': 'My favorite drink is iced coffee.\nI have a black belt in karate.\nI m in a jazz band and play the saxophone.\nI vacation along lake michigan every summer.',
#   'Best Generated Conversation': "User 1: Hi! I'm [user 1's name].\nUser 2: Hi [user 1's name], I'm [user 2's name].\nUser 1: What do you do for fun?\nUser 2: I like to play video games, go to the beach, and read.\nUser 1: I like to play video games too! I'm not much of a reader, though.\nUser 2: What video games do you like to play?\nUser 1: I like to play a lot of different games, but I'm really into competitive online games right now.\nUser 2: I'm not really into competitive games, I like to play more relaxing games.\nUser 1: That's cool. What kind of relaxing games do you like to play?\nUser 2: I like to play puzzle games, simulation games, and story-based games.\nUser 1: I've never been much of a puzzle game person, but I do like simulation games and story-based games.\nUser 2: Nice! What's your favorite simulation game?\nUser 1: I like Stardew Valley a lot. It's a farming game, but it's also really relaxing and fun.\nUser 2: I've heard good things about that game. I might have to check it out.\nUser 1: You should! It's a lot of fun.\nUser 2: Well, I'm glad we met. Maybe we can play some games together sometime.\nUser 1: That would be fun!\nUser 2: Great! I'll send you my Steam name.\nUser 1: Ok, sounds good."},
#  {'user 1 personas': 'I am 32.\nI play video games all day.\nI still live at home with my parents.\nI do not want a job.',
#   'user 2 personas': 'I have a ford f150.\nI like ford cars.\nMy truck is black.\nI also like ford trucks.\nI own a ford truck.',
#   'Best Generated Conversation': "User 1: Hey, how's it going?\nUser 2: Good, I'm just hanging out.\nUser 1: Nice. Me too. I'm playing video games.\nUser 2: Oh, cool. I like video games. What are you playing?\nUser 1: I'm playing Call of Duty: Warzone.\nUser 2: Oh, I've never played that one. What's it like?\nUser 1: It's a battle royale game. You drop into a map with 150 other players and you have to be the last one standing.\nUser 2: Oh, that sounds fun. I'll have to check it out.\nUser 1: You should. It's a lot of fun.\nUser 2: So, what else do you like to do?\nUser 1: I like to watch movies and TV shows.\nUser 2: Me too. What kind of movies and TV shows do you like?\nUser 1: I like action movies and TV shows. I also like comedy movies and TV shows.\nUser 2: Me too. I love action movies and TV shows.\nUser 1: So, what are some of your favorite movies and TV shows?\nUser 2: I love the Fast and Furious movies. I also love the Marvel Cinematic Universe.\nUser 1: Me too! I love the Fast and Furious movies and the Marvel Cinematic Universe.\nUser 2: What are your favorite TV shows?\nUser 1: I love The Walking Dead. I also love Game of Thrones.\nUser 2: Me too! I love The Walking Dead and Game of Thrones.\nUser 1: So, what are you doing this weekend?\nUser 2: I'm not sure yet. What are you doing?\nUser 1: I'm not sure either. Maybe we could hang out?\nUser 2: That sounds fun. Let's do it.\nUser 1: Great! I'll call you later to set up a time."},
#  {'user 1 personas': 'I am 32.\nI play video games all day.\nI still live at home with my parents.\nI do not want a job.\nI eat all take out.',
#   'user 2 personas': 'I can recite the movie young frankenstein word for word.\nI like to make my own clothes.\nI am partially blind.\nI do volunteer work for human rights organizations.\nI can do convincing bird calls.',
#   'Best Generated Conversation': "User 1: Hi, my name is John. What's your name?\nUser 2: Hi, John, my name is Mary.\nUser 1: It's nice to meet you, Mary. What do you do for a living?\nUser 2: I do volunteer work for human rights organizations.\nUser 1: That's really cool. I've always wanted to do some volunteer work, but I've never had the time.\nUser 2: You should definitely look into it! It's a great way to give back to the community.\nUser 1: I will. Thanks for the suggestion.\nUser 2: No problem. So, what do you do for fun?\nUser 1: I like to play video games. I'm a huge gamer.\nUser 2: Oh, that's cool. I like to play video games too. What games do you like to play?\nUser 1: I like to play all kinds of games, but I'm mostly into RPGs and strategy games.\nUser 2: Me too! I love RPGs and strategy games. They're so much fun to play.\nUser 1: I know, right? They're the best.\nUser 2: So, what are some of your favorite games?\nUser 1: I like to play a lot of different games, but some of my favorites are the Elder Scrolls series, the Fallout series, and Civilization.\nUser 2: Oh, I love the Elder Scrolls series! I've played all of them.\nUser 1: Me too! They're so good.\nUser 2: So, what do you like about them?\nUser 1: I love the open world and the freedom to do whatever you want.\nUser 2: Me too! I love that you can just explore and do whatever you want.\nUser 1: Yeah, it's the best.\nUser 2: So, what are some of your favorite things to do in the Elder Scrolls games?\nUser 1: I love to explore the world and find new things. I also love to do quests and side quests.\nUser 2: Me too! I love doing quests and side quests.\nUser 1: Yeah, they're so much fun.\nUser 2: So, what's your favorite quest in the Elder Scrolls games?\nUser 1: I think my favorite quest is the one where you have to go to the Soul Cairn.\nUser 2: Oh, that's a good one. I loved that quest too.\nUser 1: Yeah, it was so cool.\nUser 2: So, what's your favorite thing about the Soul Cairn?\nUser 1: I love the atmosphere. It's so creepy and eerie.\nUser 2: Me too! I love the atmosphere.\nUser 1: Yeah, it's the best."},
#  {'user 1 personas': 'I write.\nI work at mcdonald s.\nI watch youtube videos.\nI have brown hair.',
#   'user 2 personas': 'I want to move.\nI don t like feeling controlled.\nI wish i could take back a mistake.\nI have a harsh inner critic.\nI don t like my reputation.',
#   'Best Generated Conversation': "User 1: Hi!\nUser 2: Hey!\nUser 1: What's up?\nUser 2: Not much. Just hanging out.\nUser 1: Cool. What do you like to do for fun?\nUser 2: I like to watch YouTube videos, go to concerts, and read.\nUser 1: Nice. I like to write, watch YouTube videos, and listen to music.\nUser 2: What do you write?\nUser 1: I write poetry, short stories, and essays.\nUser 2: That's cool. I've always wanted to write a book.\nUser 1: You should try! It's a lot of fun.\nUser 2: I'm not sure if I'm good enough.\nUser 1: You don't have to be good enough. Just start writing and see what happens.\nUser 2: I'll think about it.\nUser 1: Cool. So, what do you want to do after we graduate?\nUser 2: I want to move to a new city. I'm tired of living in this one.\nUser 1: I know what you mean. I'm also ready for a change.\nUser 2: Maybe we can move to the same city.\nUser 1: That would be cool! We could be roommates.\nUser 2: That would be fun!\nUser 1: So, what are we waiting for? Let's go pack our bags!\nUser 2: Haha, okay! I'm ready!"},
#  {'user 1 personas': 'I am bald.\nI like to swim.\nMy favorite drink is chocolate milk.\nI don t work.',
#   'user 2 personas': 'My favorite store is american eagle.\nI enjoy spending time with my family.\nI love to go running.\nI do not like vegetables.',
#   'Best Generated Conversation': "User 1: Hello!\nUser 2: Hi!\nUser 1: What do you like to do for fun?\nUser 2: I love to spend time with my family, go running, and shop.\nUser 1: Oh, that's great! I love to swim and go shopping too.\nUser 2: That's awesome! We should go shopping sometime.\nUser 1: That would be fun! What's your favorite store?\nUser 2: My favorite store is American Eagle.\nUser 1: Oh, I love that store! I always find great clothes there.\nUser 2: Me too! They have a great selection of clothes.\nUser 1: What kind of clothes do you like to wear?\nUser 2: I like to wear casual clothes, like jeans and t-shirts.\nUser 1: Me too! I love how comfortable they are.\nUser 2: Me too! They're perfect for running.\nUser 1: I know, right? I love running. It's so relaxing.\nUser 2: Me too! It's a great way to get in shape.\nUser 1: I know, right? I love how I feel after I've run.\nUser 2: Me too! It's a great way to start your day.\nUser 1: I know, right? I love waking up early and going for a run.\nUser 2: Me too! It's the best way to start the day."}]

# %%
data_list = [{"persona":instance["user 1 personas"],"conversation":instance["Best Generated Conversation"]} for instance in data_list]

# %%
from transformers import BartTokenizer
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large")
add_special_tokens = {'additional_special_tokens': ['<query>', '<response>', '<latent>', '<persona>']}
tokenizer.add_special_tokens(add_special_tokens)
# Out:
# 4

# %%
args = {
   "num_latent": 10,
   "num_latent2": 10,
}

# %%
encoded_tokens = tokenizer.encode(add_special_tokens['additional_special_tokens'])
args['bos'], args["query"], args["response"], args["latent"], args["persona"], args["eos"] = encoded_tokens
args["pad"] = 1

# %%
args
# Out:
# {'num_latent': 10,
#  'num_latent2': 10,
#  'bos': 0,
#  'query': 50265,
#  'response': 50266,
#  'latent': 50267,
#  'persona': 50268,
#  'eos': 2,
#  'pad': 1}

# %%
for i, instance in enumerate(data_list):
    try:
        instance["persona"] = instance["persona"].split("\n")
        instance["conversation"] = instance["conversation"].split("\n")
        instance["persona"] = [p.strip() for p in instance["persona"] if p.strip()]
        instance["conversation"] = [c.strip() for c in instance["conversation"] if c.strip()]

        instance["conversation"] = [c.replace("User 1:", "") for c in instance["conversation"]]
        instance["conversation"] = [c.replace("User 2:", "").strip() for c in instance["conversation"]]
    except Exception as e:
        print("Error in instance:", instance)
        print("Error in instance index:", i)
        print("Exception:", e)
        continue

# %%
data_list[510]
# Out:
# {'persona': ['I love hockey.',
#   'I ve flown out of the country.',
#   'I ve a younger sibling.',
#   'My bestfriend is from out of town.',
#   'I studied business as my major.'],
#  'conversation': ["Hi, I'm [user 1 name].",
#   "Hi, I'm [user 2 name].",
#   'Nice to meet you. What do you like to do for fun?',
#   'I like to listen to rock music and play video games.',
#   "I like rock music too! What's your favorite band?",
#   'My favorite band is Led Zeppelin.',
#   "They're one of my favorites too! What's your favorite song of theirs?",
#   'My favorite song of theirs is Stairway to Heaven.',
#   "That's a great song! I love the guitar solo in that song.",
#   "Me too! It's so iconic.",
#   'So, what else do you like to do for fun?',
#   'I also like to play video games. My favorite video game is The Last of Us.',
#   "I've heard good things about that game. I've been meaning to try it.",
#   "You should! It's a great game.",
#   'So, what do you do for a living?',
#   "I'm a software engineer.",
#   "Oh, cool! I'm a business analyst.",
#   "Nice! I've always been interested in business.",
#   "Me too! It's a fascinating field.",
#   "So, what's your favorite food?",
#   'My favorite food is pizza.',
#   'Me too! I love pizza.',
#   'So, where are you from?',
#   "I'm from California.",
#   "Oh, cool! I've always wanted to go to California.",
#   "You should! It's a great place to visit.",
#   "So, what's your favorite thing about California?",
#   "My favorite thing about California is the weather. It's always sunny and warm.",
#   "That sounds amazing! I'm from the Midwest, so we get a lot of snow and cold weather.",
#   "I'm sorry to hear that. I hate the cold weather.",
#   'So, what are your plans for the future?',
#   "I'm not sure yet. I'm thinking about moving to New York City.",
#   "Oh, cool! I've always wanted to live in New York City.",
#   "You should! It's a great place to live.",
#   'So, what do you think? Should I move to New York City?',
#   "I think it would be a great decision! It's a very exciting city.",
#   "Thanks for the advice! I'm going to start looking into moving to New York City.",
#   "Good luck! I'm sure you'll love it there."]}

# %%
# data_list.pop(510)

# %%
data_list[0]
# Out:
# {'persona': ['I am 32.',
#   'I do not want a job.',
#   'I play video games all day.',
#   'I still live at home with my parents.'],
#  'conversation': ["Hi! I'm [user 1's name].",
#   "Hi [user 1's name], I'm [user 2's name].",
#   'What do you do for fun?',
#   'I like to play video games, go to the beach, and read.',
#   "I like to play video games too! I'm not much of a reader, though.",
#   'What video games do you like to play?',
#   "I like to play a lot of different games, but I'm really into competitive online games right now.",
#   "I'm not really into competitive games, I like to play more relaxing games.",
#   "That's cool. What kind of relaxing games do you like to play?",
#   'I like to play puzzle games, simulation games, and story-based games.',
#   "I've never been much of a puzzle game person, but I do like simulation games and story-based games.",
#   "Nice! What's your favorite simulation game?",
#   "I like Stardew Valley a lot. It's a farming game, but it's also really relaxing and fun.",
#   "I've heard good things about that game. I might have to check it out.",
#   "You should! It's a lot of fun.",
#   "Well, I'm glad we met. Maybe we can play some games together sometime.",
#   'That would be fun!',
#   "Great! I'll send you my Steam name.",
#   'Ok, sounds good.']}

# %%
# Initialize the found list to store the modified utterances
found = []

for i, data in enumerate(data_list):
    conversation = data["conversation"]
    persona = data["persona"]
    
    for j, utterance in enumerate(conversation):
        # Check if both names are in the same utterance
        if "[user 1's name]" in utterance and "[user 2's name]" in utterance:
            print("Found both '[user 1's name]' and '[user 2's name]' in utterance:", utterance)
            # Replace both names
            updated_utterance = utterance.replace("[user 1's name]", "Rahul").replace("[user 2's name]", "Siddharth")
            # Update the conversation with the new utterance
            data_list[i]["conversation"][j] = updated_utterance
            found.append({"i": i, "j": j, "utterance": updated_utterance})
        
        # Check and replace only [user 1's name]
        elif "[user 1's name]" in utterance:
            print("Found [user 1's name] in utterance:", utterance)
            # Replace with "Rahul Bharti"
            updated_utterance = utterance.replace("[user 1's name]", "Rahul")
            # Update the conversation with the new utterance
            data_list[i]["conversation"][j] = updated_utterance
            found.append({"i": i, "j": j, "utterance": updated_utterance})
        
        # Check and replace only [user 2's name]
        elif "[user 2's name]" in utterance:
            print("Found [user 2's name] in utterance:", utterance)
            # Replace with "Siddharth Bharti"
            updated_utterance = utterance.replace("[user 2's name]", "Siddharth")
            # Update the conversation with the new utterance
            data_list[i]["conversation"][j] = updated_utterance
            found.append({"i": i, "j": j, "utterance": updated_utterance})

# After the loop, `data_list` will be updated with the modified utterances
# and `found` will contain the changes.
# Out:
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth. What do you like to do for fun?
# Found [user 1's name] in utterance: Nice to meet you [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: It's nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Nice to meet you, [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Nice to meet you, [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: Hi, [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Nice to meet you, [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. I'm [user 1's name].
# Found [user 1's name] in utterance: Hi [user 1's name], my name is Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], my name is Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name]! I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], my name is Siddharth.
# Found [user 1's name] in utterance: Nice to meet you [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], my name is Siddharth and I'm a waitress at a local restaurant.
# Found [user 1's name] in utterance: Hi [user 1's name], my name is Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Hi [user 1's name], my name is Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], my name is Siddharth.
# Found [user 1's name] in utterance: It's nice to meet you, [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth. What do you like to do for fun?
# Found [user 1's name] in utterance: Hello! Nice to meet you, [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth. I'm a middle aged mother of two high school boys. I coexist well with my husband, but I feel lost and far away from who I truly am.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Hi [user 1's name]! My name is Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name]! I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Hi, nice to meet you, [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: It's nice to meet you, [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hello [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. I'm [user 1's name].
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hi, nice to meet you [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: Nice to meet you [user 1's name]. I'm Siddharth.
# Found [user 1's name] in utterance: Hi, [user 1's name]. I'm Siddharth. I'm from Michigan.
# Found [user 1's name] in utterance: Hi [user 1's name]. My name is Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Hello [user 1's name]. I'm Siddharth. Welcome to LA!
# Found [user 1's name] in utterance: Hi [user 1's name], I'm Siddharth.
# Found [user 1's name] in utterance: Nice to meet you, Siddharth. My name is [user 1's name].
# Found [user 1's name] in utterance: Nice to meet you, [user 1's name]. I'm Siddharth.

# %%
data_list
# Out:
# [{'persona': ['I am 32.',
#    'I do not want a job.',
#    'I play video games all day.',
#    'I still live at home with my parents.'],
#   'conversation': ["Hi! I'm Rahul.",
#    "Hi Rahul Bharti, I'm Siddharth.",
#    'What do you do for fun?',
#    'I like to play video games, go to the beach, and read.',
#    "I like to play video games too! I'm not much of a reader, though.",
#    'What video games do you like to play?',
#    "I like to play a lot of different games, but I'm really into competitive online games right now.",
#    "I'm not really into competitive games, I like to play more relaxing games.",
#    "That's cool. What kind of relaxing games do you like to play?",
#    'I like to play puzzle games, simulation games, and story-based games.',
#    "I've never been much of a puzzle game person, but I do like simulation games and story-based games.",
#    "Nice! What's your favorite simulation game?",
#    "I like Stardew Valley a lot. It's a farming game, but it's also really relaxing and fun.",
#    "I've heard good things about that game. I might have to check it out.",
#    "You should! It's a lot of fun.",
#    "Well, I'm glad we met. Maybe we can play some games together sometime.",
#    'That would be fun!',
#    "Great! I'll send you my Steam name.",
#    'Ok, sounds good.']},
#  {'persona': ['I am 32.',
#    'I play video games all day.',
#    'I still live at home with my parents.',
#    'I do not want a job.'],
#   'conversation': ["Hey, how's it going?",
#    "Good, I'm just hanging out.",
#    "Nice. Me too. I'm playing video games.",
#    'Oh, cool. I like video games. What are you playing?',
#    "I'm playing Call of Duty: Warzone.",
#    "Oh, I've never played that one. What's it like?",
#    "It's a battle royale game. You drop into a map with 150 other players and you have to be the last one standing.",
#    "Oh, that sounds fun. I'll have to check it out.",
#    "You should. It's a lot of fun.",
#    'So, what else do you like to do?',
#    'I like to watch movies and TV shows.',
#    'Me too. What kind of movies and TV shows do you like?',
#    'I like action movies and TV shows. I also like comedy movies and TV shows.',
#    'Me too. I love action movies and TV shows.',
#    'So, what are some of your favorite movies and TV shows?',
#    'I love the Fast and Furious movies. I also love the Marvel Cinematic Universe.',
#    'Me too! I love the Fast and Furious movies and the Marvel Cinematic Universe.',
#    'What are your favorite TV shows?',
#    'I love The Walking Dead. I also love Game of Thrones.',
#    'Me too! I love The Walking Dead and Game of Thrones.',
#    'So, what are you doing this weekend?',
#    "I'm not sure yet. What are you doing?",
#    "I'm not sure either. Maybe we could hang out?",
#    "That sounds fun. Let's do it.",
#    "Great! I'll call you later to set up a time."]},
#  {'persona': ['I am 32.',
#    'I play video games all day.',
#    'I still live at home with my parents.',
#    'I do not want a job.',
#    'I eat all take out.'],
#   'conversation': ["Hi, my name is John. What's your name?",
#    'Hi, John, my name is Mary.',
#    "It's nice to meet you, Mary. What do you do for a living?",
#    'I do volunteer work for human rights organizations.',
#    "That's really cool. I've always wanted to do some volunteer work, but I've never had the time.",
#    "You should definitely look into it! It's a great way to give back to the community.",
#    'I will. Thanks for the suggestion.',
#    'No problem. So, what do you do for fun?',
#    "I like to play video games. I'm a huge gamer.",
#    "Oh, that's cool. I like to play video games too. What games do you like to play?",
#    "I like to play all kinds of games, but I'm mostly into RPGs and strategy games.",
#    "Me too! I love RPGs and strategy games. They're so much fun to play.",
#    "I know, right? They're the best.",
#    'So, what are some of your favorite games?',
#    'I like to play a lot of different games, but some of my favorites are the Elder Scrolls series, the Fallout series, and Civilization.',
#    "Oh, I love the Elder Scrolls series! I've played all of them.",
#    "Me too! They're so good.",
#    'So, what do you like about them?',
#    'I love the open world and the freedom to do whatever you want.',
#    'Me too! I love that you can just explore and do whatever you want.',
#    "Yeah, it's the best.",
#    'So, what are some of your favorite things to do in the Elder Scrolls games?',
#    'I love to explore the world and find new things. I also love to do quests and side quests.',
#    'Me too! I love doing quests and side quests.',
#    "Yeah, they're so much fun.",
#    "So, what's your favorite quest in the Elder Scrolls games?",
#    'I think my favorite quest is the one where you have to go to the Soul Cairn.',
#    "Oh, that's a good one. I loved that quest too.",
#    'Yeah, it was so cool.',
#    "So, what's your favorite thing about the Soul Cairn?",
#    "I love the atmosphere. It's so creepy and eerie.",
#    'Me too! I love the atmosphere.',
#    "Yeah, it's the best."]},
#  {'persona': ['I write.',
#    'I work at mcdonald s.',
#    'I watch youtube videos.',
#    'I have brown hair.'],
#   'conversation': ['Hi!',
#    'Hey!',
#    "What's up?",
#    'Not much. Just hanging out.',
#    'Cool. What do you like to do for fun?',
#    'I like to watch YouTube videos, go to concerts, and read.',
#    'Nice. I like to write, watch YouTube videos, and listen to music.',
#    'What do you write?',
#    'I write poetry, short stories, and essays.',
#    "That's cool. I've always wanted to write a book.",
#    "You should try! It's a lot of fun.",
#    "I'm not sure if I'm good enough.",
#    "You don't have to be good enough. Just start writing and see what happens.",
#    "I'll think about it.",
#    'Cool. So, what do you want to do after we graduate?',
#    "I want to move to a new city. I'm tired of living in this one.",
#    "I know what you mean. I'm also ready for a change.",
#    'Maybe we can move to the same city.',
#    'That would be cool! We could be roommates.',
#    'That would be fun!',
#    "So, what are we waiting for? Let's go pack our bags!",
#    "Haha, okay! I'm ready!"]},
#  {'persona': ['I am bald.',
#    'I like to swim.',
#    'My favorite drink is chocolate milk.',
#    'I don t work.'],
#   'conversation': ['Hello!',
#    'Hi!',
#    'What do you like to do for fun?',
#    'I love to spend time with my family, go running, and shop.',
#    "Oh, that's great! I love to swim and go shopping too.",
#    "That's awesome! We should go shopping sometime.",
#    "That would be fun! What's your favorite store?",
#    'My favorite store is American Eagle.',
#    'Oh, I love that store! I always find great clothes there.',
#    'Me too! They have a great selection of clothes.',
#    'What kind of clothes do you like to wear?',
#    'I like to wear casual clothes, like jeans and t-shirts.',
#    'Me too! I love how comfortable they are.',
#    "Me too! They're perfect for running.",
#    "I know, right? I love running. It's so relaxing.",
#    "Me too! It's a great way to get in shape.",
#    "I know, right? I love how I feel after I've run.",
#    "Me too! It's a great way to start your day.",
#    'I know, right? I love waking up early and going for a run.',
#    "Me too! It's the best way to start the day."]},
#  {'persona': ['I am male.',
#    'I like potatoes.',
#    'I work in accounting.',
#    'I lease my car.'],
#   'conversation': ['What do you like to do for fun?',
#    'I like to watch TV and play games.',
#    'What kind of games do you like to play?',
#    'I like to play video games and board games.',
#    'I like video games too! What are your favorite games?',
#    'I like to play Mario Kart and Minecraft.',
#    "I love Mario Kart! I'm not very good at Minecraft, but I still enjoy playing it.",
#    "I'm not very good at Mario Kart, but I still enjoy playing it too.",
#    'What else do you like to do for fun?',
#    'I like to go to the park and play with my friends.',
#    'That sounds like fun! I like to go to the park too.',
#    'I also like to go to the movies.',
#    'I like to go to the movies too! What was the last movie you saw?',
#    'The last movie I saw was Frozen 2.',
#    'I loved Frozen 2! I saw it twice in theaters.',
#    "I thought it was really good too! I'm excited for the next one.",
#    "Me too! I hope it's as good as the first one.",
#    'Me too!',
#    'What are your favorite foods?',
#    'I like ham and cheese sandwiches.',
#    'I love ham and cheese sandwiches! I used to eat them all the time when I was a kid.',
#    "I still eat them all the time! They're so good.",
#    "They are! I'm glad we have something in common."]},
#  {'persona': ['I am male.',
#    'I like potatoes.',
#    'I work in accounting.',
#    'I lease my car.'],
#   'conversation': ['Hello!',
#    'Hello!',
#    'What do you do for fun?',
#    'I volunteer at animal shelters, dance, and I love to read.',
#    "That's great! What's your favorite book?",
#    "I'm not sure I have one favorite book, but I really love the Harry Potter series.",
#    "Me too! I've read the series several times.",
#    "That's awesome!",
#    'So, what do you do for work?',
#    "I'm an accountant.",
#    "Oh, that's cool. I've never met an accountant before.",
#    'Really? There are a lot of us out there.',
#    "I know, but I just haven't met one before.",
#    'Well, now you have.',
#    'Yes, I do.',
#    'So, what do you like to do for fun?',
#    'I like to play video games, watch movies, and eat potatoes.',
#    'Oh, I love potatoes too!',
#    "Really? That's great!",
#    "Yeah, they're so good.",
#    'I know, right?',
#    "So, what's your favorite kind of potato?",
#    'I like mashed potatoes the best.',
#    "Me too! They're so delicious.",
#    'Yeah, they are.',
#    "I'm glad we have something in common.",
#    'Me too.',
#    'So, what are you doing later?',
#    "I'm not sure yet. What are you doing?",
#    "I'm going to the movies. Do you want to come with me?",
#    'Sure, that sounds like fun.',
#    'Great! What movie do you want to see?',
#    "I don't know. What are you thinking?",
#    'I was thinking about seeing "The Batman".',
#    'That sounds good to me.',
#    "Great! I'll see you at the theater.",
#    'See you there!']},
#  {'persona': ['I am male.',
#    'My weakness are sweets.',
#    'I am unsociable.',
#    'I am a jack of all , master of none.'],
#   'conversation': ["What's your favorite music?",
#    'I like rock and roll.',
#    'Cool, me too! What bands do you like?',
#    'I like the Beatles, the Rolling Stones, and Led Zeppelin.',
#    'I love the Beatles! I also like the Who and Pink Floyd.',
#    "Oh, I love Pink Floyd too! What's your favorite album?",
#    'My favorite album is Dark Side of the Moon.',
#    "That's a great album! My favorite is Wish You Were Here.",
#    "That's a good one too! What's your favorite song by Pink Floyd?",
#    'My favorite song is "Comfortably Numb".',
#    "That's a great song! What's your favorite band from Russia?",
#    'I like Kino.',
#    "I've never heard of them. What kind of music do they play?",
#    "They're a rock band. They're pretty good.",
#    "I'll have to check them out. Do you like to travel?",
#    "Yeah, I love to travel. I've been to a lot of different countries.",
#    "I've only been to a few countries. I'd love to travel more.",
#    "You should! It's a great way to learn about different cultures.",
#    "I know, I know. I'll get on it.",
#    "Good! You won't regret it."]},
#  {'persona': ['I am male.',
#    'My weakness are sweets.',
#    'I am unsociable.',
#    'I live to not disappoint my loved ones.',
#    'I am a jack of all , master of none.'],
#   'conversation': ["I'm a jack of all trades, master of none.",
#    "I know what that means. I try to do a lot of things, but I'm not an expert at anything.",
#    "I'm the same way. I'm not sure if it's a good thing or a bad thing.",
#    "I think it's a good thing. It means we're always learning and trying new things.",
#    'I agree. I like to keep myself busy.',
#    "Me too. I don't like to sit around and do nothing.",
#    'What do you like to do for fun?',
#    'I like to ride my bike, draw, and spend time with my family.',
#    'Those sound like fun things to do. I like to ride my bike too.',
#    'Nice! Where do you like to ride your bike?',
#    "I like to ride my bike around my neighborhood. It's a nice place to ride.",
#    'I bet it is. I like to ride my bike around the lake.',
#    "That sounds like a nice ride. I'm sure the scenery is beautiful.",
#    "It is. It's a great place to relax and enjoy the outdoors.",
#    "I'm sure it is. I'll have to check it out sometime.",
#    "You should. It's a great place to ride a bike.",
#    'I will. Thanks for the recommendation.']},
#  {'persona': ['I am male.',
#    'I live to not disappoint my loved ones.',
#    'I am unsociable.',
#    'I am a jack of all , master of none.',
#    'My weakness are sweets.'],
#   'conversation': ["I'm not very social either. I find it easier to talk to people online than in person.",
#    'I find talking to people in person to be boring. I prefer to keep to myself.',
#    "I think it's nice to be able to socialize with people, but I understand why you prefer to be alone.",
#    "I like to be in control of my environment, and when I'm alone, I can do whatever I want without having to worry about anyone else.",
#    "That makes sense. I think it's important to have some time to yourself each day, even if you're an extrovert.",
#    "I agree. It's important to be able to relax and recharge.",
#    'Do you have any hobbies?',
#    'I like to read, write, and play video games.',
#    'Me too! I love to read and play video games.',
#    'What kind of games do you like to play?',
#    'I like to play all kinds of games, but I especially like RPGs.',
#    'Me too! I love the story and character development in RPGs.',
#    "I agree. They're really immersive and you can get really attached to the characters.",
#    "What's your favorite RPG?",
#    "It's hard to say, but I think I would have to say Final Fantasy X.",
#    "That's a good choice. It's a classic for a reason.",
#    "It is. It's one of the best games ever made.",
#    "I agree. It's so well-written and the characters are so well-developed.",
#    "I agree. It's a masterpiece.",
#    "It is. I'm glad we agree."]},
#  {'persona': ['I am male.',
#    'I live to not disappoint my loved ones.',
#    'My weakness are sweets.',
#    'I am a jack of all , master of none.',
#    'I am unsociable.'],
#   'conversation': ['My favorite music genre is rock music.',
#    'I love rock music too! What is your favorite band?',
#    'My favorite band is The Story So Far.',
#    'I have never heard of that band before. What kind of music do they play?',
#    'They are a pop punk band.',
#    'Oh, I like pop punk. What are some of their songs?',
#    'Some of their most popular songs include "Roam", "Uncomfortable", and "Keep This Up".',
#    'Those sound like good songs. I will have to check them out.',
#    'I hope you like them.',
#    'Me too.',
#    'So, what do you do for fun?',
#    'I enjoy going to festivals.',
#    'That sounds like fun. What kind of festivals do you go to?',
#    'I like going to music festivals, art festivals, and food festivals.',
#    'Music festivals are always a good time. I have been to a few myself.',
#    'Which festivals have you been to?',
#    'I have been to Coachella, Bonnaroo, and Lollapalooza.',
#    'Those are all great festivals. I have always wanted to go to Coachella.',
#    'It is a great festival. I have been to it twice.',
#    'Maybe I will go to Coachella next year.',
#    'I hope you do. It is a great experience.',
#    'Thanks for the recommendation.',
#    'No problem.']},
#  {'persona': ['I am male.',
#    'I live to not disappoint my loved ones.',
#    'I am a jack of all , master of none.',
#    'My weakness are sweets.'],
#   'conversation': ["I'm glad that you have a nice truck, do you use it for work or fun?",
#    "I use it for both work and fun, it's a great truck!",
#    'What kind of work do you do?',
#    "I'm a construction worker, so I need a truck that can handle a lot of work.",
#    "That makes sense, I'm sure you get a lot of use out of it.",
#    'I do, I use it every day.',
#    'What do you like to do for fun with your truck?',
#    'I like to go camping, fishing, and hunting.',
#    "That sounds like a lot of fun! I've never been camping or fishing, but I've always wanted to try.",
#    "You should definitely try it, it's a lot of fun.",
#    'Maybe I will.',
#    "I'm sure you would like it.",
#    "I'm glad that you enjoy your truck, it sounds like a great vehicle.",
#    'It is, I love it.',
#    "What's your favorite thing about it?",
#    'I love how it can handle a lot of work and still be fun to drive.',
#    'That sounds like a great truck.',
#    "It is, I'm really happy with it."]},
#  {'persona': ['I am tall.',
#    'I like to garden.',
#    'I love the outdoors.',
#    'I like to build things.',
#    'I like to travel.'],
#   'conversation': ['Hello, my name is [username].',
#    'Hello [username], my name is [username].',
#    "It's nice to meet you. What do you like to do for fun?",
#    'I enjoy playing soccer, working in finance, and renting apartments.',
#    "I'm glad to hear you enjoy playing soccer. I've always wanted to learn how to play.",
#    "It's a great sport! You should definitely give it a try.",
#    "I might just do that. What's your favorite thing about soccer?",
#    'I like the teamwork and the excitement of the game.',
#    "I can see how that would be fun. I'm more of an outdoors person myself. I like to garden, hike, and travel.",
#    "That sounds like a lot of fun! I love to be outside too, but I'm not as good at gardening as you.",
#    "I'm sure you're a great gardener! What kind of plants do you like to grow?",
#    'I like to grow vegetables, flowers, and herbs.',
#    "That's great! I'm not very good at growing vegetables, but I love flowers and herbs.",
#    "I'm sure you could learn to grow vegetables if you wanted to.",
#    "Maybe I will! I'm always looking for new ways to challenge myself.",
#    "That's the spirit! I'm sure you'd be a great gardener.",
#    'Thanks! I appreciate your encouragement.']},
#  {'persona': ['I am tall.',
#    'I like to build things.',
#    'I love the outdoors.',
#    'I like to garden.',
#    'I like to travel.'],
#   'conversation': ["Hey! What's up?",
#    'Not much, just watching Rick and Morty.',
#    "Oh, that's cool. I've never seen it before. What's it about?",
#    "It's a really funny show about a mad scientist and his grandson.",
#    'That sounds interesting. I might have to check it out.',
#    "You should! It's really funny.",
#    'So, what do you do for fun?',
#    "I like to write. I'm actually writing a novel right now.",
#    "Oh, that's awesome! What's it about?",
#    "It's about a group of friends who go on a road trip.",
#    'That sounds really cool. I love road trips.',
#    "Me too! They're the best way to see the country.",
#    "So, what's your favorite thing to do outdoors?",
#    "I love to go hiking. There's a great trail near my house that I love to hike.",
#    'Oh, that sounds really nice. I love hiking too.',
#    'Do you like to garden?',
#    'I do! I have a small garden in my backyard.',
#    "That's awesome! I love to garden, too.",
#    "It's so relaxing.",
#    'I agree.',
#    "So, what's your favorite color?",
#    'My favorite color is black.',
#    "Oh, that's interesting. Mine is green.",
#    'I like green too.',
#    'So, what do you do for work?',
#    "I'm a software engineer.",
#    "Oh, that's cool. I've always been interested in coding.",
#    "It's a lot of fun.",
#    "So, what's your favorite thing about yourself?",
#    "I'm always up for a good adventure.",
#    "That's a good quality.",
#    'Thanks. I think so too.',
#    'So, what do you think we should do for our next conversation?',
#    "I don't know. What do you want to do?",
#    'We could talk about our favorite books.',
#    'That sounds good. I love to talk about books.']},
#  {'persona': ['I am tall.',
#    'I spend my free time volunteering at nursing homes.',
#    'I like to water ski.',
#    'My favorite color is red.'],
#   'conversation': ['What are some of your interests?',
#    'I love to travel, I like to be outdoors, I like to read, and I like to volunteer.',
#    'Those are all great interests! I like to travel too, I like to be outdoors too, and I like to read too.',
#    "That's great! What are some of your favorite places to travel to?",
#    'I love to go to the beach, I love to go to the mountains, and I love to go to the city.',
#    'Those are all great places to travel to! I love going to the beach too, I love going to the mountains too, and I love going to the city too.',
#    'We have a lot in common! What are some of your favorite books?',
#    'I love to read historical fiction, I love to read mysteries, and I love to read romance novels.',
#    'Those are all great genres! I love to read historical fiction too, I love to read mysteries too, and I love to read romance novels too.',
#    'We have even more in common! What are some of your favorite volunteer activities?',
#    'I like to volunteer at nursing homes, I like to volunteer at homeless shelters, and I like to volunteer at animal shelters.',
#    'Those are all great places to volunteer at! I like to volunteer at nursing homes too, I like to volunteer at homeless shelters too, and I like to volunteer at animal shelters too.',
#    'We are so much alike! I think we would make great friends.',
#    'I agree! We should get together and do something fun soon.',
#    "That sounds like a great idea! I'll call you and we can make plans.",
#    "Sounds good! I'm looking forward to it."]},
#  {'persona': ['I am tall.',
#    'I spend my free time volunteering at nursing homes.',
#    'My favorite color is red.',
#    'My dad was a cop.',
#    'I like to water ski.'],
#   'conversation': ['Hi there!',
#    'Hello!',
#    'What do you like to do for fun?',
#    'I like to work in my garden, create art, and listen to Ween.',
#    'That sounds great! I love to water ski and volunteer at nursing homes.',
#    'Wow! Volunteering at nursing homes is great.',
#    "It is! It's really rewarding to help out people who need it.",
#    "I'm sure it is.",
#    "I'm also tall, my favorite color is red, and my dad was a cop.",
#    "Wow! You're tall! I'm not very tall, I'm actually short for a guy.",
#    "It's okay to be short!",
#    "Thanks! I'm not really bothered by it, but it can be a little annoying sometimes.",
#    'I can imagine.',
#    "I'm glad you're not bothered by it!",
#    "Thanks! It's not a big deal.",
#    "I'm glad you feel that way.",
#    'So, what else do you like to do for fun?',
#    'I love to go to concerts, watch movies, and play video games.',
#    "I love to go to concerts too! I've been to a lot of concerts in my life.",
#    "That's great! What's your favorite band?",
#    'My favorite band is Radiohead.',
#    "Oh, I love Radiohead! They're so good.",
#    "They are! I've seen them in concert a few times.",
#    "That's awesome! I've always wanted to see them in concert.",
#    'You should go! They put on a great show.',
#    'I will! Thanks for the recommendation.']},
#  {'persona': ['I am thin.',
#    'I like to hunt.',
#    'I am blonde.',
#    'I like the tv show the walking dead.',
#    'I love the tigers baseball team.'],
#   'conversation': ['Hi there!',
#    'Hello!',
#    'What do you like to do for fun?',
#    'I like to edit, watch tv, and play games.',
#    'I like to watch tv too! What are your favorite shows?',
#    'I like The Walking Dead, Breaking Bad, and The Office.',
#    "Me too! I love The Walking Dead. What's your favorite season?",
#    'I think my favorite season is season 5. It was really intense and had a lot of great character development.',
#    'I agree! I loved how they introduced the new characters and how the story unfolded.',
#    "Me too! It was so well done. What about you, what's your favorite season?",
#    'I think my favorite season is season 7. It was so exciting and had a lot of great twists and turns.',
#    'I agree! I loved how they killed off Glenn and Abraham. It was so unexpected.',
#    'Me too! It was so shocking. What do you think of the new season?',
#    "I think it's been really good so far. I love the new characters and the story is really interesting.",
#    "Me too! I'm excited to see what happens next.",
#    "Me too! It's going to be a lot of fun.",
#    "I'm glad we have the same taste in tv shows!",
#    'Me too! It makes it more fun to talk about them.',
#    'So, what else do you like to do for fun?',
#    'I like to play games too. I play a lot of video games and board games.',
#    'I like video games too! What are your favorite games?',
#    'I like a lot of different games, but my favorites are probably The Last of Us, Red Dead Redemption 2, and Persona 5.',
#    "I've heard good things about all of those games! I've been meaning to check them out.",
#    "You definitely should! They're all great games. What about you, what are your favorite games?",
#    'I like a lot of different games too, but my favorites are probably The Legend of Zelda: Breath of the Wild, Super Mario Odyssey, and Hollow Knight.',
#    "I've heard good things about all of those games too! I've been meaning to check them out.",
#    "You definitely should! They're all great games."]},
#  {'persona': ['I am thin.',
#    'I like to hunt.',
#    'I love the tigers baseball team.',
#    'I am blonde.',
#    'I like the tv show the walking dead.'],
#   'conversation': ['Hello!',
#    'Hello! How are you today?',
#    "I'm doing well, thanks for asking! I'm a big fan of the Tigers baseball team. Do you like baseball?",
#    "I love baseball! I'm a big fan of the St. Louis Cardinals.",
#    "Oh, that's cool! I've been to a few Cardinals games. They're a great team.",
#    "They are! I'm glad to hear you've been to a few games.",
#    "Yeah, I've been to a few Tigers games too. They're a lot of fun.",
#    "I'm sure they are! I've always wanted to go to a Tigers game.",
#    "You should! They're a great team to watch.",
#    'I will! Thanks for the suggestion.',
#    'No problem! What else do you like to do for fun?',
#    'I love to go dancing. I also love country music.',
#    "Oh, that's cool! I love to dance too. I'm not very good at it, but I enjoy it.",
#    "I'm sure you're better than you think! I'm not very good at it either, but I have fun doing it.",
#    'We should go dancing together sometime!',
#    "That would be fun! I'd love to dance with you.",
#    'Great! We can set it up for next weekend.',
#    'Sounds good!',
#    'What else do you like to do for fun?',
#    'I love animals. I have a farm with pigs, horses, and hens.',
#    "Oh, that's cool! I love animals too. I have a cat and a dog.",
#    "I love cats and dogs! They're the best animals.",
#    "I agree! They're so cute and cuddly.",
#    'They are! I love to play with them.',
#    "Me too! They're always so happy to see me.",
#    "They are! I'm glad we agree on animals.",
#    "Me too! They're the best.",
#    "I'm glad we're getting along so well.",
#    "Me too! I'm having a lot of fun talking to you.",
#    "I am too! You're so easy to talk to.",
#    "Thank you! You're too!",
#    "I'm glad we met.",
#    'Me too']},
#  {'persona': ['I am thin.',
#    'I like the tv show the walking dead.',
#    'I like to hunt.',
#    'I love the tigers baseball team.'],
#   'conversation': ['Hi there!',
#    'Hi there!',
#    "What's your name?",
#    "I'm Sarah.",
#    'Nice to meet you, Sarah. My name is Chris.',
#    'Nice to meet you too, Chris.',
#    'Where are you from?',
#    'I recently moved to Sweden from the US.',
#    "Oh, that's cool! Why did you move?",
#    'I wanted to experience something new.',
#    "I can understand that. What's your favorite thing about Sweden so far?",
#    'I love the nature. There are so many beautiful places to hike and camp.',
#    'That sounds amazing! I love hiking too.',
#    "Me too! I'm actually going hiking in the mountains this weekend.",
#    "That sounds like a lot of fun! I'm a bit jealous.",
#    'You should come with me!',
#    "I would love to, but I'm not sure I can make it.",
#    "Oh, that's too bad. Maybe next time.",
#    'Yeah, maybe.',
#    'So, what do you do for fun?',
#    'I like to watch TV, read, and go hunting.',
#    'Oh, I love to watch TV too! What do you like to watch?',
#    'I like to watch a lot of different things, but my favorite show is The Walking Dead.',
#    "I've never seen that show. What's it about?",
#    "It's about a group of survivors who are trying to find a safe place to live after a zombie apocalypse.",
#    'That sounds really interesting. I might have to check it out.',
#    "You should! It's really good.",
#    'So, what do you like to hunt?',
#    "I usually hunt deer, but I've also hunted elk and bear.",
#    "That sounds like a lot of fun! I've never been hunting before.",
#    "You should try it sometime! It's a great way to get outdoors and enjoy nature.",
#    'I might have to!']},
#  {'persona': ['I m dumpy.',
#    'I have long fingers.',
#    'I can t eat shrimp.',
#    'Like a skeleton.',
#    'I have long legs.'],
#   'conversation': ["I'm really tall, do you know anyone taller than me?",
#    'My twin brother is taller than you, by a little bit.',
#    "Oh wow, I'm not used to seeing someone taller than me.",
#    "Yeah, he's pretty tall.",
#    'So, what do you like to do for fun?',
#    'I like to bake cakes, and read books.',
#    "That's cool! I like to read books too.",
#    "What's your favorite book?",
#    'My favorite book is The Lord of the Rings.',
#    "Oh, that's a great book! I've read it a few times.",
#    "Me too! It's so good.",
#    "What's your favorite part?",
#    'The part where Frodo and Sam are climbing Mt. Doom.',
#    "Oh yeah, that's a great part.",
#    "I know! It's so suspenseful.",
#    'Yeah, it is.',
#    'What do you like to do for work?',
#    "I'm a baker.",
#    "That's awesome! I love baking cakes.",
#    "Yeah, it's a lot of fun.",
#    "What's your favorite kind of cake to bake?",
#    'I like to make chocolate cakes.',
#    'Oh yeah, I love chocolate cake!',
#    "Yeah, it's so good.",
#    "What's your favorite thing about your job?",
#    'I like seeing people enjoy my cakes.',
#    "That's a great feeling.",
#    'Yeah, it is.',
#    "What's your favorite thing about yourself?",
#    "I'm a hard worker.",
#    "That's a great quality to have.",
#    'Yeah, I think so too.',
#    "What's your favorite thing about me?",
#    "I don't know you that well yet.",
#    'Well, what do you like about the conversation so far?',
#    "I like that you're so tall.",
#    "Thanks! I'm glad you like it.",
#    "I like that you're so interested in my job.",
#    "Thank you! I'm glad you're so passionate about it.",
#    "I like that you're so easy to talk to.",
#    "Thank you! I'm glad you think so."]},
#  {'persona': ['I m funny.',
#    'I can draw.',
#    'I have sausage fingers.',
#    'I like sprite soda.'],
#   'conversation': ['Hi, my name is [name].',
#    "Hi, I'm [name].",
#    'Where are you from?',
#    'I live in Vermont.',
#    "Oh, that's cool. I've always wanted to visit Vermont.",
#    "You should! It's beautiful here.",
#    "I'm sure it is. I've heard great things about it.",
#    'What do you like to do for fun?',
#    "I like to draw, I'm funny, and I like sprite soda.",
#    "Oh, that's cool. I like to hike, I also like to mountain bike, and I've visited 12 national parks in the US.",
#    "Wow, that's awesome! I've never been to a national park.",
#    "You should! They're really beautiful.",
#    "I will! I'm sure I'd love it.",
#    "I'm glad to hear that. So, what do you do for a living?",
#    "I'm an environmental activist.",
#    "Oh, that's great! I'm really passionate about environmental issues.",
#    "Me too! I think it's so important to protect our planet.",
#    "I totally agree. It's the only one we have.",
#    'Exactly.',
#    "So, what's your favorite thing about Vermont?",
#    "I love the nature here. It's so beautiful.",
#    'Me too! The mountains are amazing.',
#    'And the lakes are so peaceful.',
#    'I know, right? I love to go kayaking on the lakes.',
#    "That sounds like fun. I've never been kayaking before.",
#    "You should try it! It's a lot of fun.",
#    "I will! I'm sure I'd love it.",
#    "I'm glad to hear that. So, what do you do for fun in Vermont?",
#    'I like to go hiking, I also like to mountain bike, and I like to draw.',
#    "Oh, that's cool. I like to do all of those things too!",
#    "That's awesome! We should go hiking or mountain biking together sometime.",
#    "That would be great! I'd love to."]},
#  {'persona': ['I am a man.',
#    'I am not healthy.',
#    'I like the movie godfather.',
#    'I weight 300 pounds.',
#    'I like candy and soda.'],
#   'conversation': ["Hi, I'm Rahul.",
#    "Hi, I'm Siddharth.",
#    'What do you like to do for fun?',
#    'I like baking, especially wedding cakes.',
#    "That's cool! I've never been to a wedding with a cake that I didn't like.",
#    "Thanks! I'm pretty proud of my work.",
#    "What's your favorite thing about baking?",
#    "I love the creativity and the challenge. It's always fun to come up with new ideas and see them come to life.",
#    "That's awesome! I'm not very creative, so I'm always impressed by people who are.",
#    "Thanks! I'm sure you're creative in your own way.",
#    "I guess so. I'm not sure what my talents are, though.",
#    "Well, you seem like a nice person, and you're good at holding a conversation.",
#    'Thanks! I try.',
#    'So, what else do you like to do for fun?',
#    'I like to watch movies, play video games, and go for walks.',
#    'Me too! I love going to the theater to watch movies.',
#    "I love the theater too! It's so much better than watching movies at home.",
#    "I agree! It's so much more immersive.",
#    'Do you have any pets?',
#    'Yes, I have a dog.',
#    'What kind of dog?',
#    'A golden retriever.',
#    'Golden retrievers are so cute! I love dogs.',
#    "Me too! They're the best.",
#    'Well, it was nice talking to you. I hope we can chat again sometime.',
#    'You too! It was nice talking to you too.']},
#  {'persona': ['I am a man.',
#    'I work on trucks.',
#    'I have a doberman.',
#    'I am twenty five years old.',
#    'My favorite food is pizza.'],
#   'conversation': ['What do you do for work?',
#    "I'm a lifeguard at a beach.",
#    "Cool! I've always wanted to be a lifeguard.",
#    "It's a lot of fun, but it can be dangerous.",
#    'I bet. Do you ever have to save anyone?',
#    'A few times, yeah.',
#    "What's it like to save someone's life?",
#    "It's a really rewarding feeling.",
#    "I can imagine. So, what's your favorite part of the job?",
#    'The best part is getting to help people.',
#    "That's a good answer. What's your least favorite part of the job?",
#    'The worst part is the long hours.',
#    'I can imagine. Do you have any interesting stories from your time as a lifeguard?',
#    'Yeah, I have a few.',
#    'Like what?',
#    'Well, one time, I had to save a kid who was drowning.',
#    'Oh no! What happened?',
#    'He was playing in the ocean and he got caught in a riptide.',
#    "That's scary. How did you save him?",
#    'I swam out to him and pulled him to shore.',
#    "Wow, that's amazing! You're a hero!",
#    'Thanks, but I was just doing my job.',
#    "You saved someone's life. That's more than just your job. That's heroic.",
#    "Thanks. It's good to hear that you appreciate it."]},
#  {'persona': ['I am a man.',
#    'I have a doberman.',
#    'I work on trucks.',
#    'I am twenty five years old.'],
#   'conversation': ["Hi, I'm [user 1 name].",
#    "Hi, I'm [user 2 name].",
#    'What do you do for a living?',
#    "I'm a pediatrician.",
#    "Oh, that's cool. I'm a mechanic.",
#    "That's interesting. What kind of trucks do you work on?",
#    'I work on all kinds of trucks, but I specialize in diesel trucks.',
#    "That's cool. I've always been interested in diesel trucks.",
#    "They're pretty cool. They're a lot more powerful than gas trucks.",
#    "I can imagine. I'm more of a family man, so I don't need anything too powerful.",
#    "That's understandable. I have a doberman.",
#    "Oh, I love dogs! What's his name?",
#    'His name is Max.',
#    "That's a great name.",
#    'Thanks. So, what do you like to do for fun?',
#    "I like to bowl. I'm pretty good at it.",
#    "That's cool. I've never been bowling before.",
#    "You should try it sometime. It's a lot of fun.",
#    "I'll have to give it a try.",
#    "You won't regret it.",
#    'Good to know.',
#    'So, what do you do for fun?',
#    'I like to go fishing. I also like to go hiking and camping.',
#    'That sounds like fun. I love to go camping too.',
#    'We should go camping together sometime.',
#    'That would be great.',
#    "I'll bring the fishing gear.",
#    "And I'll bring the food.",
#    'Sounds good.',
#    'So, what are your plans for the weekend?',
#    "I'm not sure yet. What are yours?",
#    "I'm going to bowl with my family.",
#    "That sounds like fun. I'm going to go fishing with my friends.",
#    'That sounds like a good time too.',
#    'It should be.',
#    "I'm sure you'll have a great time.",
#    "Thanks. I'm looking forward to it."]},
#  {'persona': ['I am a man.',
#    'My favorite food is pizza.',
#    'I work on trucks.',
#    'I have a doberman.'],
#   'conversation': ["Hi! I'm Rahul.",
#    "Hello! I'm Siddharth.",
#    'What do you do for a living?',
#    "I'm a stay-at-home mom.",
#    'Oh, cool! I work on trucks.',
#    "That's interesting. Do you like it?",
#    "Yeah, it's a lot of fun. I get to work on different kinds of trucks every day.",
#    'That sounds cool. I like working with animals. I have three dogs and a parrot.',
#    "Wow, that's a lot of animals! I have a doberman.",
#    "I love animals. They're so cute and cuddly.",
#    "I agree. They're the best.",
#    'So, what do you like to do for fun?',
#    'I like to play video games, watch movies, and go to the gym.',
#    'That sounds like fun. I like to play bingo every Wednesday with my husband.',
#    "That's cool. I've never played bingo before.",
#    "You should try it! It's a lot of fun.",
#    'I might just do that.',
#    'You should!',
#    "So, what's your favorite food?",
#    "I love pizza. It's my favorite food.",
#    "That's my favorite food too!",
#    'What kind of pizza do you like?',
#    'I like all kinds of pizza, but my favorite is pepperoni.',
#    'Me too! I love pepperoni pizza.',
#    "So, what's your favorite jazz song?",
#    'I love "Fly Me to the Moon" by Frank Sinatra.',
#    "That's a great song! I love it too.",
#    "It's such a classic.",
#    'It is.',
#    'So, what do you think of my profile?',
#    "I think it's great! You seem like a really interesting person.",
#    "Thank you! I think you're a really interesting person too."]},
#  {'persona': ['I am blind.',
#    'I use a cane to help me get around.',
#    'I have many friends.',
#    'I have a job as a dj at a radio station.'],
#   'conversation': ["Hi, I'm John. I'm a blind DJ.",
#    "Hi, I'm Mary. I'm engaged to be married.",
#    'Congratulations! What are your plans for the wedding?',
#    "We're still working on the details, but we're thinking about having it on the beach.",
#    "That sounds beautiful! I'm sure it will be a great day.",
#    "Thanks, I'm really excited about it.",
#    'So, what do you do for a living?',
#    "I'm a historian. I love learning about the past.",
#    "That's really interesting! I'm not very good at history, but I find it fascinating.",
#    "Well, there's always time to learn! What are some of your favorite things to do?",
#    "I love to play music and I'm also a big fan of sports.",
#    "That's great! I love music too. What kind of music do you play?",
#    "I play the piano and I also sing. I'm a big fan of jazz and blues music.",
#    "That's awesome! I love jazz too. I play the saxophone.",
#    "Really? That's great! We should play together sometime.",
#    "That would be fun! I'd love to.",
#    "Great! I'll let you know when I'm free.",
#    'Sounds good!']},
#  {'persona': ['I am blind.',
#    'I once drove a car ! my friend told me what to do while i drove.',
#    'I have many friends.',
#    'I have a job as a dj at a radio station.',
#    'I use a cane to help me get around.'],
#   'conversation': ['Hi there!',
#    'Hi, how are you?',
#    "I'm doing well, thanks! How about you?",
#    "I'm doing great, thanks!",
#    "That's good to hear! I'm blind, but I still manage to live a very active life. I have a job as a DJ at a local radio station and I have many friends. I even used to drive a car, but I had to give that up because it was too dangerous.",
#    "That's amazing! I'm so impressed that you're able to live such a full and independent life. I'm sure it's not always easy, but you seem to be doing great.",
#    "Thank you! It's definitely not always easy, but I'm grateful for the support of my friends and family.",
#    "That's wonderful. I'm glad you have such a great support system.",
#    'Me too! So, what do you like to do for fun?',
#    'I love to garden. I have a small plot in my backyard where I grow vegetables, herbs, and flowers. I also like to read and spend time with my family.',
#    'That sounds great! I love gardening too. I have a small garden in my backyard where I grow tomatoes, peppers, and cucumbers. I also like to read and spend time with my friends.',
#    "That's awesome! It sounds like we have a lot in common.",
#    'Yeah, it does! We should get together sometime and garden together.',
#    "That would be fun! I'd love to.",
#    "Great! I'll give you a call sometime next week and we can set something up.",
#    "Sounds good! I'll look forward to it.",
#    'Me too!']},
#  {'persona': ['I am blind.',
#    'I once drove a car ! my friend told me what to do while i drove.',
#    'I use a cane to help me get around.',
#    'I have a job as a dj at a radio station.'],
#   'conversation': ['Hey, what do you do for a living?',
#    'I drive a truck for a living.',
#    "That's cool. I've always wanted to try driving a truck.",
#    "It's pretty fun. I get to see a lot of different places.",
#    "That's awesome. I've only been to a few different places in my life.",
#    "Well, if you ever need a ride, I'm always happy to give you one.",
#    "Thanks, I'll keep that in mind.",
#    'No problem. So, what do you do for fun?',
#    "I'm a DJ at a radio station.",
#    "That's cool! I love listening to the radio.",
#    'Thanks. I like to play all sorts of different music.',
#    "What's your favorite type of music to play?",
#    'I like to play a lot of different genres, but my favorite is probably electronic music.',
#    "I love electronic music! It's so upbeat and energetic.",
#    "Me too! It's perfect for getting pumped up.",
#    "I know right? I love listening to it when I'm working out.",
#    "Me too! It's the best way to get motivated.",
#    'So, what are your favorite bands?',
#    'I love Daft Punk, Disclosure, and Odesza.',
#    "I love Daft Punk too! They're one of my favorite bands.",
#    "Me too! They're so creative and innovative.",
#    "I know right? They're always pushing the boundaries of music.",
#    "I love that about them. They're always coming up with new ideas.",
#    "Me too! They're one of my biggest inspirations.",
#    "Me too! They're just amazing."]},
#  {'persona': ['I am blind.',
#    'I once drove a car ! my friend told me what to do while i drove.',
#    'I have a job as a dj at a radio station.',
#    'I have many friends.'],
#   'conversation': ['What do you do for work?',
#    "I'm a chef at a small restaurant.",
#    'Oh, that sounds interesting. Do you like it?',
#    'I love it! I get to cook all day long, and I get to meet a lot of interesting people.',
#    "That's awesome! I'm a DJ at a radio station.",
#    "Oh, that's cool! I've always been curious about how radio stations work.",
#    "It's pretty fun! I get to play music for people all day long, and I get to interact with listeners.",
#    'That sounds like a great job!',
#    'It is! I love it.',
#    "So, what's your favorite thing about being a DJ?",
#    "My favorite thing is getting to play music for people. I love seeing the reactions on people's faces when they hear a song they love.",
#    "That's a great feeling! I love seeing people's faces light up when they taste my food.",
#    "I bet you do! You're a really good cook.",
#    'Thank you! I appreciate that.',
#    "So, what's your favorite thing to cook?",
#    "I love making pasta dishes. I think they're so delicious and comforting.",
#    'I agree! Pasta dishes are the best.',
#    "I'm glad you agree! So, what do you like to do for fun?",
#    'I love to go to concerts. I also like to go to the movies.',
#    "I love going to concerts too! I've seen some of my favorite bands live.",
#    "Me too! I've seen a few of my favorite bands live as well.",
#    "That's awesome! I'm glad we have some things in common.",
#    "Me too! It's nice to meet someone who likes the same things as me.",
#    'Yeah, it is! I think we could be good friends.',
#    'I think so too!']},
#  {'persona': ['I am dumpy.',
#    'Like a skeleton.',
#    'I have long legs.',
#    'I have long fingers.',
#    'I cannot eat shrimp.'],
#   'conversation': ["Hi, I'm Rahul.",
#    "Hi, I'm Siddharth.",
#    'What do you like to do for fun?',
#    'I like to hang out with friends, play video games, and watch movies.',
#    'Oh, that sounds like fun. I like to do those things too.',
#    'Me too!',
#    "What's your favorite video game?",
#    'I like to play a lot of different games, but my favorite is probably Minecraft.',
#    "I've never played Minecraft. What's it about?",
#    "It's a sandbox game where you can build anything you want. You can build houses, castles, farms, cities, whatever you want.",
#    'That sounds really cool! I might have to check it out.',
#    "You should! It's a lot of fun.",
#    "So, what's your favorite movie?",
#    'I like a lot of different movies, but my favorite is probably The Shawshank Redemption.',
#    "Oh, that's a great movie! I love the ending.",
#    "Me too! It's so hopeful.",
#    "So, what's your favorite book?",
#    'I like a lot of different books, but my favorite is probably To Kill a Mockingbird.',
#    "That's a great book! I loved reading it in school.",
#    "Me too! It's so powerful.",
#    'So, what do you do for a living?',
#    "I'm a teacher.",
#    "Oh, that's great! I love teachers.",
#    'Thanks! I love my job.',
#    'What grade do you teach?',
#    'I teach fifth grade.',
#    "Oh, that's a great age!",
#    "It is! They're so funny and smart.",
#    "I'm sure they're a lot of fun to teach.",
#    'They are! I love my job.',
#    'It sounds like you have a lot of interests.',
#    'I do! I like to keep busy.',
#    "That's great! I'm the same way.",
#    "I'm glad to hear it."]},
#  {'persona': ['I am funny.',
#    'I have sausage fingers.',
#    'I can draw.',
#    'I am bloated.'],
#   'conversation': ['What do you like to do for fun?',
#    'I love to quilt and spend time with my grandchildren.',
#    'Quilting sounds very interesting. What do you like about it?',
#    'I love the creativity and the sense of accomplishment I get when I finish a quilt.',
#    'That makes sense. I can see how that would be very rewarding.',
#    'It is. I love it when I can create something beautiful that someone else can enjoy.',
#    "I'm sure your grandchildren love your quilts.",
#    'They do. They love to snuggle up with them on cold winter nights.',
#    "That's so sweet. I'm sure they'll cherish those quilts for years to come.",
#    'I hope so. I put a lot of love into them.',
#    'I can tell. What else do you like to do?',
#    "I also love to read. I'm always looking for new books to read.",
#    'Me too! I love getting lost in a good book.',
#    "Me too. It's the best way to relax and escape from the real world.",
#    'I agree. What are some of your favorite books?',
#    'I love the Harry Potter series, the Lord of the Rings series, and the Hunger Games series.',
#    "Me too! I've read them all multiple times.",
#    "Me too! They're so good.",
#    "I'm glad you like them too. I'm always looking for new people to talk to about books.",
#    "Me too. It's always nice to meet someone who shares your love of reading."]},
#  {'persona': ['I am funny.',
#    'I have sausage fingers.',
#    'I like sprite soda.',
#    'I am bloated.',
#    'I can draw.'],
#   'conversation': ['Hi there!',
#    'Hello!',
#    'What are you up to today?',
#    'Not much, just watching TV.',
#    'Oh, what are you watching?',
#    "I'm watching a documentary about the history of cars.",
#    'Oh, that sounds interesting! I love history.',
#    "Me too! I'm a big fan of old cars.",
#    'Me too! I love the look of old cars.',
#    "Me too! They're so stylish.",
#    'So, what kind of cars do you like?',
#    "I like all kinds of cars, but I'm a big fan of muscle cars.",
#    'Oh, me too! I love the power of those cars.',
# ...
#    "You're welcome. I'm always here for you."]},
#  {'persona': ['I got a new job.',
#    'I like cats.',
#    'I like to travel.',
#    'I like cars.',
#    'Favorite color is green.'],
#   'conversation': ['Hello, my name is [user 1 name].',
#    'Hello, my name is [user 2 name].',
#    'Nice to meet you. What do you like to do for fun?',
#    'I like to travel, read, and spend time with my friends and family.',
#    'I love to travel too! I have been to a few different countries. Where have you been?',
#    'I have been to Mexico, Canada, and the United States. I would love to travel to Europe one day.',
#    'Europe is amazing! I have been to France, Italy, and Spain. I would love to go back to Europe one day.',
#    'I love to read too! I mostly read fiction, but I also like to read nonfiction. What kind of books do you like to read?',
#    'I like to read a variety of books, but I mostly read fiction. I love fantasy, science fiction, and historical fiction. What are some of your favorite books?',
#    "I love the Harry Potter series! I also love the Lord of the Rings series and the Hunger Games series. I have also read a lot of historical fiction, but I don't have a favorite author yet.",
#    "Those are all great books! I love the Harry Potter series too. I also love the Lord of the Rings series. I haven't read the Hunger Games series yet, but I have heard good things about it.",
#    'The Hunger Games series is really good! I read it all in one week. I would definitely recommend it.',
#    "I'll have to check it out. Thanks for the recommendation!",
#    "You're welcome!",
#    'So, what do you do for work?',
#    "I'm a teacher. I teach kindergarten.",
#    "That's awesome! I always wanted to be a teacher, but I'm not good at math.",
#    "Math can be hard, but it's not impossible! I'm sure you could do it if you put your mind to it.",
#    "Thanks, but I think I'll stick to reading.",
#    "That's a good choice! Reading is a great way to learn new things.",
#    'I agree!',
#    'So, what do you like to do for fun?',
#    'I like to travel, read, and spend time with my friends and family.',
#    'I like to do a lot of the same things! I love to travel, read, and spend time with my friends and family.',
#    'It sounds like we have a lot in common.',
#    'I think so too!',
#    'It was nice talking to you.',
#    'You too!']},
#  {'persona': ['I got a new job.',
#    'Favorite color is green.',
#    'I like cats.',
#    'I like cars.'],
#   'conversation': ["Hey, what's up?",
#    'Not much, just working.',
#    'What do you do for work?',
#    "I'm a waitress at a local restaurant.",
#    'Oh, that sounds fun.',
#    "It's okay, but it can be tough sometimes.",
#    "What's your favorite thing about your job?",
#    'I like meeting new people and making them happy.',
#    "That's a great quality to have.",
#    'Thanks! What do you do for work?',
#    'I just got a new job as a marketing manager.',
#    "That's awesome! Congratulations!",
#    "Thanks! I'm really excited about it.",
#    "What's your favorite color?",
#    'Green.',
#    "That's my favorite color too!",
#    "Really? That's cool.",
#    "Yeah, I think it's a really calming color.",
#    'I agree.',
#    'So, what do you like to do for fun?',
#    'I like to go hiking, play video games, and watch movies.',
#    'That sounds like a lot of fun. I like to go hiking too.',
#    "That's great! We should go hiking together sometime.",
#    'That would be fun!',
#    "Cool. I'll have to get your number.",
#    'Okay.']},
#  {'persona': ['I hate broccoli.',
#    'I design video games for a living.',
#    'My mom is my best friend.',
#    'Rock music is my favorite.',
#    'I am afraid of the dark.'],
#   'conversation': ['Hey!',
#    "Hey! What's up?",
#    'Not much, just working on a new video game design.',
#    "That's cool! I'm not very good at video games, but I enjoy watching people play them.",
#    "Oh, really? What's your favorite kind of video game?",
#    'I like action games and adventure games. I also like games that are really scary.',
#    'Me too! I love the adrenaline rush you get from playing a scary game.',
#    "I know, right? It's so much fun!",
#    "So, what's your favorite scary game?",
#    "My favorite scary game is Silent Hill. It's so creepy and atmospheric.",
#    "I've never played Silent Hill, but I've heard good things about it.",
#    "You should definitely try it! It's a classic.",
#    'I will! Thanks for the recommendation.',
#    'No problem! So, what else do you do for fun?',
#    'I like to read, go for walks, and hang out with my friends.',
#    'That sounds like fun! I like to do those things too.',
#    'What are some of your favorite books?',
#    'I like horror novels and books about serial killers.',
#    "Oh, I've never read any books about serial killers.",
#    "They're really interesting! I like to learn about the psychology of serial killers.",
#    "I can see why that would be interesting. I'm not sure if I'm brave enough to read a book about a serial killer, though.",
#    "It can be a little scary, but it's also really fascinating.",
#    "Maybe I'll give it a try.",
#    "You should! It's definitely worth it."]},
#  {'persona': ['I hate broccoli.',
#    'I design video games for a living.',
#    'Rock music is my favorite.',
#    'My mom is my best friend.'],
#   'conversation': ["Hi, I'm [user 1]. What do you like to do for fun?",
#    "Hi, I'm [user 2]. I like to play video games, and I also enjoy writing in my spare time.",
#    "Oh, that's cool! I also enjoy video games. What kind of games do you like to play?",
#    "I like to play a variety of games, but I'm especially a fan of RPGs and adventure games.",
#    "Me too! I love RPGs and adventure games. What's your favorite RPG?",
#    "My favorite RPG is probably The Witcher 3. It's such a great game with a deep and immersive story.",
#    "I love The Witcher 3! It's one of my favorite games too.",
#    "What's your favorite adventure game?",
#    "My favorite adventure game is probably The Legend of Zelda: Breath of the Wild. It's such a beautiful and open world game.",
#    "I love Breath of the Wild! It's one of my favorite games too.",
#    'So, do you work in the gaming industry?',
#    'No, I actually work at a hotel overnight.',
#    "Oh, that's cool! Do you like working at a hotel?",
#    "I do, it's a lot of fun. I get to meet a lot of different people.",
#    "That's good to hear!",
#    'What do you do for work?',
#    "I'm a video game designer.",
#    "Oh, that's cool! What kind of video games do you design?",
#    "I design a variety of games, but I'm mostly focused on RPGs and adventure games.",
#    "That's really cool! I'd love to see some of your work sometime.",
#    "Sure, I'd be happy to show you some of my work.",
#    'Thanks!',
#    'No problem.']},
#  {'persona': ['I hate cleaning.',
#    'I work in finance.',
#    'I m italian american.',
#    'I paint with watercolors.',
#    'My favorite color is blue.'],
#   'conversation': ["Hi, I'm Rahul.",
#    "Hi, I'm Siddharth.",
#    'What do you like to do for fun?',
#    "I love to dance. I'm on a competitive dance team.",
#    "That's so cool! I wish I could dance.",
#    "You should try it! It's a lot of fun.",
#    "I'm not sure I'm coordinated enough.",
#    'You never know until you try!',
#    "I guess you're right.",
#    'So, what do you do for fun?',
#    'I work in finance, but I paint with watercolors in my spare time.',
#    "That's so interesting! Do you sell your paintings?",
#    'No, I just do them for fun.',
#    "I think you should sell them! I'm sure people would love them.",
#    'Maybe I will someday.',
#    'I hope you do!',
#    'Thank you.',
#    "So, what's your favorite color?",
#    'Blue.',
#    "Me too! It's such a calming color.",
#    'I agree.',
#    "So, what's your favorite Disney movie?",
#    'The Little Mermaid.',
#    "That's my favorite too!",
#    'I love Ariel.',
#    "Me too! She's so brave and independent.",
#    'I agree.',
#    'So, what are some of your other hobbies?',
#    'I love to read, go for walks, and spend time with my family.',
#    'That sounds like a lot of fun.',
#    "It is! I'm a pretty simple person.",
#    'Me too. I like to keep things simple.',
#    "I think it's the best way to live."]},
#  {'persona': ['I hate cleaning.',
#    'I work in finance.',
#    'I am italian american.',
#    'I paint with watercolors.'],
#   'conversation': ["Hi, I'm [user 1 name].",
#    "Hi, I'm [user 2 name].",
#    "It's nice to meet you. What do you do for a living?",
#    "I'm a teacher.",
#    "Oh, that's cool. I work in finance.",
#    'Really? That must be interesting.',
#    "It's okay. It's not as exciting as teaching, I'm sure.",
#    "I don't know about that. I think teaching can be pretty stressful.",
#    "It can be, but it's also really rewarding.",
#    "I'm sure it is. What do you like to do in your free time?",
#    'I like to paint with watercolors.',
#    "Oh, that's cool. I've never been very good at art.",
#    "It's not hard to learn. You should give it a try.",
#    'Maybe I will. What else do you like to do?',
#    'I like to go kayaking.',
#    "Oh, that sounds fun. I've never been kayaking before.",
#    "You should try it. It's a lot of fun.",
#    'Maybe I will.',
#    'So, what are you doing this weekend?',
#    "I'm not sure yet. I might go kayaking with some friends.",
#    "That sounds like fun. I'm going to be painting.",
#    "Oh, that sounds cool. I'd love to see some of your paintings sometime.",
#    "I'll be sure to send you some pictures.",
#    "Thanks. I'd love to see them.",
#    'So, what do you like about teaching?',
#    'I like the interaction with the students. I also like seeing them learn and grow.',
#    'That sounds really rewarding.',
#    "It is. It's the best part of the job.",
#    'So, what grade do you teach?',
#    'I teach third grade.',
#    "Oh, that's great. I love third graders. They're so funny.",
#    "They are. They're my favorite grade to teach.",
#    "So, what's the biggest challenge you face as a teacher?",
#    'The biggest challenge is keeping the students engaged.',
#    'I can imagine.',
#    'Yeah, it can be tough sometimes.',
#    "But it sounds like you're doing a great job.",
#    'Thanks. I try my best.',
#    "So, what's your favorite thing to do outside of work?",
#    'I like to go kayaking.',
#    "Oh, that sounds fun. I've never been kayaking before.",
#    "You should try it. It's a lot of fun.",
#    'Maybe I will.',
#    'So, what are you doing this weekend?',
#    "I'm not sure yet. I might go kayaking with some friends.",
#    "That sounds like fun. I'm going to be painting.",
#    "Oh, that sounds cool. I'd love to see some of your paintings sometime.",
#    "I'll be sure to send you some pictures.",
#    "Thanks. I'd love to see them."]},
#  {'persona': ['I hate cleaning.',
#    'I paint with watercolors.',
#    'My favorite color is blue.',
#    'I m italian american.'],
#   'conversation': ['I love watercolors! What are some of your favorite subjects to paint?',
#    'I love painting landscapes, especially mountains.',
#    'Me too! I love the way the colors of the sky and the mountains can change so much depending on the time of day.',
#    'Me too! I also like painting flowers.',
#    "I love flowers too! They're so beautiful and delicate.",
#    "Yeah, they're great subjects. Do you like to paint with other people?",
#    "I've never tried it, but I'd love to give it a try.",
#    "It's a lot of fun! I've been painting with a group of friends for a few years now and we always have a great time.",
#    "That sounds really fun! I'll have to find a group to paint with.",
#    "You should! It's a great way to meet new people and learn new techniques.",
#    'Yeah, it sounds like it.',
#    'So, what else do you like to do for fun?',
#    "I love going to the beach. I'm Italian American so I love seafood.",
#    "I love the beach too! I'm deaf so I love the way the waves sound.",
#    "That's so cool! I love the way the waves look.",
#    "Yeah, they're so beautiful.",
#    "So, what's your favorite kind of seafood?",
#    'I love shrimp, lobster, and crabs.',
#    'Me too! I love shrimp the most.',
#    'Me too! I love the way they taste.',
#    "Yeah, they're so good.",
#    "So, what do you like to do when you're not painting or going to the beach?",
#    'I love to watch movies and play video games.',
#    "I love movies too! I'm deaf so I love to read the subtitles.",
#    "That's so cool! I love the way the actors look.",
#    "Yeah, they're so beautiful.",
#    "So, what's your favorite movie?",
#    'I love the Lord of the Rings trilogy.',
#    'Me too! I love the way the characters are developed.',
#    "Yeah, they're so well written.",
#    'So, what do you love about video games?',
#    'I love the way they can transport me to another world.',
#    "Me too! I love the way they can make me feel like I'm doing something amazing.",
#    "Yeah, they're so great.",
#    "So, what's your favorite video game?",
#    'I love the Legend of Zelda series.',
#    'Me too! I love the way the characters are designed.',
#    "Yeah, they're so cool."]},
#  {'persona': ['I hate cleaning.',
#    'My favorite color is blue.',
#    'I paint with watercolors.',
#    'I work in finance.',
#    'I m italian american.'],
#   'conversation': ['Hi, my name is Rahul.',
#    'Hello, my name is Siddharth.',
#    'What do you do for fun?',
#    "I'm a dancer, a pianist, and I love to sing.",
#    "Wow, that's amazing! I'm a finance worker, but I love to paint with watercolors.",
#    "That's so cool! I love art.",
#    "Me too! I'm also Italian-American.",
#    "That's interesting! I'm a vegetarian.",
#    "Oh, I've never met a vegetarian before. What's it like?",
#    "It's great! I feel better for it, and I love animals.",
#    "That's awesome! I'm glad you're happy.",
#    'Thanks! So, what else do you like to do?',
#    'I love to travel, go to concerts, and hang out with friends.',
#    "That sounds like fun! I love to travel too, but I don't get to go very often.",
#    'You should come with me sometime!',
#    'I would love to!',
#    "Great! I'll have to plan something.",
#    'Sounds good!',
#    'So, what are you doing later today?',
#    "I'm going to a dance class.",
#    "Oh, that sounds fun! I've always wanted to take a dance class.",
#    "You should! It's a great way to exercise and have fun.",
#    'I will!',
#    'Great!',
#    "So, what's your favorite dance?",
#    'I love to salsa dance.',
#    "Oh, that's one of my favorites too!",
#    'We should go salsa dancing sometime!',
#    'That would be fun!',
#    'Great! We can exchange numbers and make plans.',
#    'Sounds good!']},
#  {'persona': ['I hate to drive.',
#    'I am younger then 46.',
#    'I like the taste of cheese.',
#    'I need to take 4 pills a day to live.'],
#   'conversation': ["Hi, I'm [user 1 name].",
#    "Hi, I'm [user 2 name].",
#    'What do you do for fun?',
#    'I listen to death metal.',
#    "Oh, that's cool. I've never really listened to death metal before.",
#    "You should! It's really good.",
#    "I'll have to try it sometime.",
#    "You won't regret it.",
#    'What do you like about it?',
#    'The music is really intense and it makes me feel like I can do anything.',
#    'That sounds like it would be a lot of fun.',
#    'It is! I love it.',
#    'What else do you like to do for fun?',
#    'I also like to play video games and go for walks.',
#    'I like video games too!',
#    'What kind of games do you like to play?',
#    'I like to play action-adventure games and RPGs.',
#    "I like those too! I'm playing a lot of Skyrim right now.",
#    "I love Skyrim! I've played through it several times.",
#    "I'm still on my first playthrough, but I'm really enjoying it.",
#    "It's a great game.",
#    'It is!',
#    'So, what are you studying in college?',
#    "I'm studying computer science.",
#    "Oh, cool! I'm in the medical field.",
#    "That's cool! I've always been interested in medicine.",
#    "It's a great field. I'm a nurse.",
#    "That's awesome! I've always thought about being a nurse.",
#    "It's a great job.",
#    "I'm sure it is.",
#    "So, what's your mom like?",
#    "She's great! She's a janitor at my school.",
#    "That's cool! I've never met a janitor before.",
#    "You should meet my mom! She's really nice.",
#    "I'll have to do that sometime.",
#    "You won't regret it."]},
#  ...]

# %%
data_ids = [
    {
        "persona":[tokenizer.encode(persona) for persona in instance['persona']],
        "conversation":[tokenizer.encode(utterance) for utterance in instance['conversation']]
    }
    
    for instance in data_list
]

# %%
for dat in data_ids:
    for persona in dat['persona']:
       persona.pop(0)

# %%
for dat in data_ids:
    for i,utter in enumerate(dat['conversation']):
        if i % 2 == 0:
            utter[0] = args["query"]
        else:
            utter[0] = args["response"]

# %%
data_ids[0]
# Out:
# {'persona': [[100, 95, 2162, 10, 1518, 92, 790, 4, 2],
#   [100, 101, 7, 3836, 23, 5, 950, 4, 2],
#   [100, 422, 10, 2335, 41227, 334, 4, 2],
#   [100, 33, 10, 380, 4045, 13495, 4, 2],
#   [100, 101, 602, 8, 6016, 842, 462, 16731, 4, 2]],
#  'conversation': [[50265,
#    30086,
#    6,
#    38,
#    437,
#    646,
#    44518,
#    112,
#    18,
#    766,
#    8174,
#    653,
#    18,
#    110,
#    766,
#    116,
#    2],
#   [50266,
#    30086,
#    6,
#    38,
#    437,
#    646,
#    44518,
#    132,
#    18,
#    766,
#    8174,
#    85,
#    18,
#    2579,
#    7,
#    972,
#    47,
#    4,
#    2],
#   [50265, 41541, 7, 972, 47, 350, 4, 653, 32, 47, 2509, 11, 116, 2],
#   [50266,
#    100,
#    101,
#    7,
#    972,
#    92,
#    82,
#    6,
#    310,
#    7017,
#    6664,
#    354,
#    14650,
#    6,
#    8,
#    1930,
#    86,
#    19,
#    127,
#    284,
#    4,
#    2],
#   [50265,
#    11195,
#    32,
#    70,
#    372,
#    383,
#    7,
#    28,
#    2509,
#    11,
#    4,
#    38,
#    101,
#    7,
#    3836,
#    23,
#    5,
#    950,
#    6,
#    422,
#    10,
#    2335,
#    41227,
#    334,
#    6,
#    8,
#    3529,
#    10,
#    319,
#    9,
#    29842,
#    4,
#    2],
#   [50266,
#    1711,
#    18,
#    2679,
#    4,
#    38,
#    348,
#    393,
#    1145,
#    1268,
#    54,
#    1237,
#    10,
#    2335,
#    41227,
#    334,
#    137,
#    4,
#    2],
#   [50265,
#    243,
#    18,
#    10,
#    319,
#    9,
#    1531,
#    4,
#    38,
#    120,
#    7,
#    173,
#    19,
#    3678,
#    358,
#    183,
#    8,
#    244,
#    106,
#    1532,
#    141,
#    7,
#    18871,
#    4,
#    2],
#   [50266, 1711, 4428, 101, 10, 372, 633, 4, 38, 657, 3678, 4, 2],
#   [50265, 5096, 350, 328, 252, 214, 5, 275, 4, 2],
#   [50266, 100, 33, 10, 28522, 1440, 12134, 4, 91, 18, 127, 275, 1441, 4, 2],
#   [50265,
#    100,
#    657,
#    27756,
#    328,
#    38,
#    341,
#    7,
#    33,
#    10,
#    28522,
#    77,
#    38,
#    21,
#    10,
#    4607,
#    4,
#    2],
#   [50266, 1711, 18, 6344, 4, 653, 21, 63, 766, 116, 2],
#   [50265, 9962, 766, 21, 20683, 4, 91, 21, 10, 1275, 12, 24845, 29432, 4, 2],
#   [50266, 100, 657, 5, 766, 20683, 4, 85, 18, 98, 3035, 4, 2],
#   [50265, 22086, 4, 38, 802, 98, 350, 4, 2],
#   [50266,
#    100,
#    437,
#    7785,
#    52,
#    1145,
#    4,
#    85,
#    18,
#    2579,
#    7,
#    1067,
#    7,
#    951,
#    54,
#    3829,
#    3678,
#    8,
#    27756,
#    4,
#    2],
#   [50265,
#    5096,
#    350,
#    4,
#    85,
#    18,
#    460,
#    2579,
#    7,
#    972,
#    951,
#    54,
#    34,
#    1122,
#    3168,
#    4,
#    2],
#   [50266, 100, 1034, 52, 64, 6713, 66, 456, 11133, 4, 2],
#   [50265,
#    100,
#    1017,
#    657,
#    14,
#    4,
#    166,
#    64,
#    213,
#    310,
#    7017,
#    6664,
#    354,
#    14650,
#    50,
#    120,
#    103,
#    2480,
#    6353,
#    4,
#    2],
#   [50266, 1711, 4428, 101, 10, 563, 4, 2],
#   [50265, 19065, 4, 38, 581, 2788, 47, 423, 4, 2],
#   [50266, 45953, 205, 4, 36255, 4, 2],
#   [50265, 2765, 242, 4, 2]]}

# %%
def get_history_windows(data, window_size=5):
    history_windows = []
    labels = []
    for i in range(len(data) - 1):
        if data[i][0] == args["query"]:
            window = []
            # add the query itself first
            window.append(data[i])

            # move backwards and collect previous turns (up to window_size)
            j = i - 1
            while j >= 0 and len(window) < window_size:
                window.insert(0, data[j])
                j -= 1
            
            history_windows.append(window)
            labels.append(data[i + 1])

    return history_windows,labels

# %%
history_windows, labels = get_history_windows(data_ids[0]['conversation'], window_size=5)

# %%
from itertools import chain

for l in history_windows:
    # print(l[0])
    ids= list(chain.from_iterable(l))
    print(ids)
    print(tokenizer.decode(ids))
# Out:
# [50265, 30086, 6, 38, 437, 646, 44518, 112, 18, 766, 8174, 653, 18, 110, 766, 116, 2]
# <query> Hi, I'm [User 1's name]. What's your name?</s>
# [50265, 30086, 6, 38, 437, 646, 44518, 112, 18, 766, 8174, 653, 18, 110, 766, 116, 2, 50266, 30086, 6, 38, 437, 646, 44518, 132, 18, 766, 8174, 85, 18, 2579, 7, 972, 47, 4, 2, 50265, 41541, 7, 972, 47, 350, 4, 653, 32, 47, 2509, 11, 116, 2]
# <query> Hi, I'm [User 1's name]. What's your name?</s> <response> Hi, I'm [User 2's name]. It's nice to meet you.</s> <query> Nice to meet you too. What are you interested in?</s>
# [50265, 30086, 6, 38, 437, 646, 44518, 112, 18, 766, 8174, 653, 18, 110, 766, 116, 2, 50266, 30086, 6, 38, 437, 646, 44518, 132, 18, 766, 8174, 85, 18, 2579, 7, 972, 47, 4, 2, 50265, 41541, 7, 972, 47, 350, 4, 653, 32, 47, 2509, 11, 116, 2, 50266, 100, 101, 7, 972, 92, 82, 6, 310, 7017, 6664, 354, 14650, 6, 8, 1930, 86, 19, 127, 284, 4, 2, 50265, 11195, 32, 70, 372, 383, 7, 28, 2509, 11, 4, 38, 101, 7, 3836, 23, 5, 950, 6, 422, 10, 2335, 41227, 334, 6, 8, 3529, 10, 319, 9, 29842, 4, 2]
# <query> Hi, I'm [User 1's name]. What's your name?</s> <response> Hi, I'm [User 2's name]. It's nice to meet you.</s> <query> Nice to meet you too. What are you interested in?</s> <response> I like to meet new people, play ultimate frisbee, and spend time with my family.</s> <query> Those are all great things to be interested in. I like to dance at the club, run a dog obedience school, and eat a lot of sweets.</s>
# [50265, 41541, 7, 972, 47, 350, 4, 653, 32, 47, 2509, 11, 116, 2, 50266, 100, 101, 7, 972, 92, 82, 6, 310, 7017, 6664, 354, 14650, 6, 8, 1930, 86, 19, 127, 284, 4, 2, 50265, 11195, 32, 70, 372, 383, 7, 28, 2509, 11, 4, 38, 101, 7, 3836, 23, 5, 950, 6, 422, 10, 2335, 41227, 334, 6, 8, 3529, 10, 319, 9, 29842, 4, 2, 50266, 1711, 18, 2679, 4, 38, 348, 393, 1145, 1268, 54, 1237, 10, 2335, 41227, 334, 137, 4, 2, 50265, 243, 18, 10, 319, 9, 1531, 4, 38, 120, 7, 173, 19, 3678, 358, 183, 8, 244, 106, 1532, 141, 7, 18871, 4, 2]
# <query> Nice to meet you too. What are you interested in?</s> <response> I like to meet new people, play ultimate frisbee, and spend time with my family.</s> <query> Those are all great things to be interested in. I like to dance at the club, run a dog obedience school, and eat a lot of sweets.</s> <response> That's interesting. I've never met anyone who runs a dog obedience school before.</s> <query> It's a lot of fun. I get to work with dogs every day and help them learn how to behave.</s>
# [50265, 11195, 32, 70, 372, 383, 7, 28, 2509, 11, 4, 38, 101, 7, 3836, 23, 5, 950, 6, 422, 10, 2335, 41227, 334, 6, 8, 3529, 10, 319, 9, 29842, 4, 2, 50266, 1711, 18, 2679, 4, 38, 348, 393, 1145, 1268, 54, 1237, 10, 2335, 41227, 334, 137, 4, 2, 50265, 243, 18, 10, 319, 9, 1531, 4, 38, 120, 7, 173, 19, 3678, 358, 183, 8, 244, 106, 1532, 141, 7, 18871, 4, 2, 50266, 1711, 4428, 101, 10, 372, 633, 4, 38, 657, 3678, 4, 2, 50265, 5096, 350, 328, 252, 214, 5, 275, 4, 2]
# <query> Those are all great things to be interested in. I like to dance at the club, run a dog obedience school, and eat a lot of sweets.</s> <response> That's interesting. I've never met anyone who runs a dog obedience school before.</s> <query> It's a lot of fun. I get to work with dogs every day and help them learn how to behave.</s> <response> That sounds like a great job. I love dogs.</s> <query> Me too! They're the best.</s>
# [50265, 243, 18, 10, 319, 9, 1531, 4, 38, 120, 7, 173, 19, 3678, 358, 183, 8, 244, 106, 1532, 141, 7, 18871, 4, 2, 50266, 1711, 4428, 101, 10, 372, 633, 4, 38, 657, 3678, 4, 2, 50265, 5096, 350, 328, 252, 214, 5, 275, 4, 2, 50266, 100, 33, 10, 28522, 1440, 12134, 4, 91, 18, 127, 275, 1441, 4, 2, 50265, 100, 657, 27756, 328, 38, 341, 7, 33, 10, 28522, 77, 38, 21, 10, 4607, 4, 2]
# <query> It's a lot of fun. I get to work with dogs every day and help them learn how to behave.</s> <response> That sounds like a great job. I love dogs.</s> <query> Me too! They're the best.</s> <response> I have a turtle named Timothy. He's my best friend.</s> <query> I love turtles! I used to have a turtle when I was a kid.</s>
# [50265, 5096, 350, 328, 252, 214, 5, 275, 4, 2, 50266, 100, 33, 10, 28522, 1440, 12134, 4, 91, 18, 127, 275, 1441, 4, 2, 50265, 100, 657, 27756, 328, 38, 341, 7, 33, 10, 28522, 77, 38, 21, 10, 4607, 4, 2, 50266, 1711, 18, 6344, 4, 653, 21, 63, 766, 116, 2, 50265, 9962, 766, 21, 20683, 4, 91, 21, 10, 1275, 12, 24845, 29432, 4, 2]
# <query> Me too! They're the best.</s> <response> I have a turtle named Timothy. He's my best friend.</s> <query> I love turtles! I used to have a turtle when I was a kid.</s> <response> That's awesome. What was its name?</s> <query> His name was Leonardo. He was a red-eared slider.</s>
# [50265, 100, 657, 27756, 328, 38, 341, 7, 33, 10, 28522, 77, 38, 21, 10, 4607, 4, 2, 50266, 1711, 18, 6344, 4, 653, 21, 63, 766, 116, 2, 50265, 9962, 766, 21, 20683, 4, 91, 21, 10, 1275, 12, 24845, 29432, 4, 2, 50266, 100, 657, 5, 766, 20683, 4, 85, 18, 98, 3035, 4, 2, 50265, 22086, 4, 38, 802, 98, 350, 4, 2]
# <query> I love turtles! I used to have a turtle when I was a kid.</s> <response> That's awesome. What was its name?</s> <query> His name was Leonardo. He was a red-eared slider.</s> <response> I love the name Leonardo. It's so cool.</s> <query> Thanks. I thought so too.</s>
# [50265, 9962, 766, 21, 20683, 4, 91, 21, 10, 1275, 12, 24845, 29432, 4, 2, 50266, 100, 657, 5, 766, 20683, 4, 85, 18, 98, 3035, 4, 2, 50265, 22086, 4, 38, 802, 98, 350, 4, 2, 50266, 100, 437, 7785, 52, 1145, 4, 85, 18, 2579, 7, 1067, 7, 951, 54, 3829, 3678, 8, 27756, 4, 2, 50265, 5096, 350, 4, 85, 18, 460, 2579, 7, 972, 951, 54, 34, 1122, 3168, 4, 2]
# <query> His name was Leonardo. He was a red-eared slider.</s> <response> I love the name Leonardo. It's so cool.</s> <query> Thanks. I thought so too.</s> <response> I'm glad we met. It's nice to talk to someone who likes dogs and turtles.</s> <query> Me too. It's always nice to meet someone who has similar interests.</s>
# [50265, 22086, 4, 38, 802, 98, 350, 4, 2, 50266, 100, 437, 7785, 52, 1145, 4, 85, 18, 2579, 7, 1067, 7, 951, 54, 3829, 3678, 8, 27756, 4, 2, 50265, 5096, 350, 4, 85, 18, 460, 2579, 7, 972, 951, 54, 34, 1122, 3168, 4, 2, 50266, 100, 1034, 52, 64, 6713, 66, 456, 11133, 4, 2, 50265, 100, 1017, 657, 14, 4, 166, 64, 213, 310, 7017, 6664, 354, 14650, 50, 120, 103, 2480, 6353, 4, 2]
# <query> Thanks. I thought so too.</s> <response> I'm glad we met. It's nice to talk to someone who likes dogs and turtles.</s> <query> Me too. It's always nice to meet someone who has similar interests.</s> <response> I hope we can hang out again sometime.</s> <query> I'd love that. We can go play ultimate frisbee or get some ice cream.</s>
# [50265, 5096, 350, 4, 85, 18, 460, 2579, 7, 972, 951, 54, 34, 1122, 3168, 4, 2, 50266, 100, 1034, 52, 64, 6713, 66, 456, 11133, 4, 2, 50265, 100, 1017, 657, 14, 4, 166, 64, 213, 310, 7017, 6664, 354, 14650, 50, 120, 103, 2480, 6353, 4, 2, 50266, 1711, 4428, 101, 10, 563, 4, 2, 50265, 19065, 4, 38, 581, 2788, 47, 423, 4, 2]
# <query> Me too. It's always nice to meet someone who has similar interests.</s> <response> I hope we can hang out again sometime.</s> <query> I'd love that. We can go play ultimate frisbee or get some ice cream.</s> <response> That sounds like a plan.</s> <query> Great. I'll text you later.</s>

# %%
for lable in labels:
    print(tokenizer.decode(lable))
# Out:
# <response> Hi, I'm [User 2's name]. It's nice to meet you.</s>
# <response> I like to meet new people, play ultimate frisbee, and spend time with my family.</s>
# <response> That's interesting. I've never met anyone who runs a dog obedience school before.</s>
# <response> That sounds like a great job. I love dogs.</s>
# <response> I have a turtle named Timothy. He's my best friend.</s>
# <response> That's awesome. What was its name?</s>
# <response> I love the name Leonardo. It's so cool.</s>
# <response> I'm glad we met. It's nice to talk to someone who likes dogs and turtles.</s>
# <response> I hope we can hang out again sometime.</s>
# <response> That sounds like a plan.</s>
# <response> Sounds good. Bye.</s>

# %%
tokenizer.decode(list(chain.from_iterable(data_ids[0]['persona'])))
# Out:
# 'I just bought a brand new house.</s>I like to dance at the club.</s>I run a dog obedience school.</s>I have a big sweet tooth.</s>I like taking and posting selkies.</s>'

# %%
# args['bos'], args["query"], args["response"], args["latent"], args["persona"], args["eos"]

# %%
instance['persona']
# Out:
# ['I love to hang out with my friends.',
#  'I love playing sports and being active.',
#  'I am a 22 year old girl.',
#  'I am in college studying education.',
#  'I love rap music.']

# %%
from itertools import chain

train_data = []

for instance in data_ids:
    history_windows, labels = get_history_windows(instance['conversation'],window_size=5)

    for window, label in zip(history_windows, labels):
        train_data.append({
            "input_ids": [args["latent"], args["persona"]] 
                          + list(chain.from_iterable(instance['persona'])) 
                          + list(chain.from_iterable(window)),
            "labels": label
        })

# %%
tokenizer.decode(train_data[0]['input_ids'])
# Out:
# "<latent> <persona> I just bought a brand new house.</s>I like to dance at the club.</s>I run a dog obedience school.</s>I have a big sweet tooth.</s>I like taking and posting selkies.</s> <query> Hi, I'm [User 1's name]. What's your name?</s>"

# %%
tokenizer.decode(train_data[0]['labels'])
# Out:
# "<response> Hi, I'm [User 2's name]. It's nice to meet you.</s>"

# %%
import pickle

# # Save the trainset to a pickle file
# with open('trainset.pkl', 'wb') as f_train:
#     pickle.dump(trainset, f_train)

# print("trainset saved to 'trainset.pkl'")

# Save the valset to a pickle file
with open('./Synthetic-Persona-Chat/prepared_data/train_data.pkl', 'wb') as f_val:
    pickle.dump(train_data, f_val)
